# %% [markdown]
# EvoGGen - Reproducing Behaviour via Evolutionary Grammar-Based Input Generation
# ===
#
# **EvoGGen**, an acronym for Evolutionary Grammar-Based Input Generation, is an advanced extension of _EvoGFuzz_. It deploys evolutionary optimization strategies to systematically generate inputs that reproduce particular behaviours. The primary objective of EvoGGen is to learn a probabilistic grammar that encapsulates the characteristics of a user-specified behaviour. Consequently, it can generate new, unseen inputs that can trigger this defined behaviour, thereby expanding the boundaries of behaviour-oriented input generation.
#
# Contrasting with EvoGFuzz: While the principal objective of EvoGFuzz is the detection of inputs inducing failures, EvoGGen aims for a different goal. It seeks to not only reproduce a predefined behaviour but also to generalize it, thereby broadening the range of inputs capable of triggering such behaviour.

# %%
import math

def calculator(inp: str) -> float:
    """
        A simple calculator function that can evaluate arithmetic expressions 
        and perform basic trigonometric functions and square root calculations.
    """
    return eval(
        str(inp), {"sqrt": math.sqrt, "sin": math.sin, "cos": math.cos, "tan": math.tan}
    )

# %%
# Make sure you use the OracleResult from the evogfuzz library
from debugging_framework.input.oracle import OracleResult

def oracle(inp: str):
    """
    This function serves as an oracle or intermediary that catches and handles exceptions 
    generated by the 'calculator' function. The oracle function is used in the context of fuzz testing.
    It aims to determine whether an input triggers a bug in the 'calculator' function.

    Args:
        inp (str): The input string to be passed to the 'calculator' function.

    Returns:
        OracleResult: An enumerated type 'OracleResult' indicating the outcome of the function execution.
            - OracleResult.PASSING: Returned if the calculator function executes without any exception or only with CalculatorSyntaxError
            - OracleResult.FAILING: Returned if the calculator function raises a ValueError exception, indicating a potential bug.
    """
    try:
        calculator(inp)
    except ValueError as e:
        return OracleResult.FAILING, e
    
    return OracleResult.PASSING, None

# %%
initial_inputs = ['sqrt(-1)', 'cos(912)', 'tan(4)']

for inp in initial_inputs:
    print(inp.ljust(20), oracle(inp))
# Out:
# sqrt(-1)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# cos(912)             (<OracleResult.PASSING: 'PASSING'>, None)
# tan(4)               (<OracleResult.PASSING: 'PASSING'>, None)

# %%
from debugging_framework.types import Grammar
from debugging_framework.fuzzingbook.grammar import is_valid_grammar

CALCGRAMMAR: Grammar = {
    "<start>":
        ["<function>(<term>)"],

    "<function>":
        ["sqrt", "tan", "cos", "sin"],
    
    "<term>": ["-<value>", "<value>"], 
    
    "<value>":
        ["<integer>.<integer>",
         "<integer>"],

    "<integer>":
        ["<digit><integer>", "<digit>"],

    "<digit>":
        ["1", "2", "3", "4", "5", "6", "7", "8", "9"]
}
    
assert is_valid_grammar(CALCGRAMMAR)

# %%
from evogfuzz.evogfuzz_class import EvoGGen

egg = EvoGGen(
    grammar=CALCGRAMMAR,
    inputs=['sqrt(-1.2)'],
    oracle=oracle,
    transform_grammar=True,
    iterations=20
)

# %%
grammar, _ = egg.optimize()

# %%
from debugging_framework.fuzzingbook.probalistic_fuzzer import ProbabilisticGrammarFuzzer

prob_fuzzer = ProbabilisticGrammarFuzzer(grammar)

for _ in range(100):
    inp = prob_fuzzer.fuzz()
    print(inp.ljust(20), oracle(inp))
# Out:
# sqrt(-1.399741)      (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-8.873)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-6.5)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-7.1)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-86.9857)       (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-178.1)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-2.6)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.175)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-4.61)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-3821)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.71)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-21)            (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-62.4)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1411)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-7.77)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-7)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.2)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.1)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-6.48)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.6)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.5)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-5)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.2)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.2)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-51.4)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-7.1)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-4579.928)      (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-3)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.2)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.1)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.2)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.84)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-11)            (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.3)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.2)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-11.5)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.1)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-211)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1355.7891)     (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-63)            (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-15.11)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-323.13)        (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-5831.4)        (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-6.31)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.481)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.7)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-51.51)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-91.387)        (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-5)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-51.41)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-7)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.677)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-4.1)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-63)            (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-6)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.625)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.33)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-11.54)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-9.3)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.1)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-91.29)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-61.15)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-5)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.85)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-6.386)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-61)            (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-51.1)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.1)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-6.65)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.38)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-3874.2)        (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-3.6)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-2.1)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-6.3)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-9.8439921)     (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-5)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-81.33)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1.1)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-9.8)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-91.7)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-631.7)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-654711.97)     (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-5.183)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-6)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-8)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-795.1)         (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-5.9)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-7.2)           (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-1)             (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
# sqrt(-3.79)          (<OracleResult.FAILING: 'FAILING'>, ValueError('math domain error'))
